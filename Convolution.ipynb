# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmina-hub/AGI_Project/blob/main/Convolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from skimage import data, color
import scipy.ndimage as ndi
from scipy.signal import convolve2d

# %%
image = cv2.imread('image_conv.webp')
image_grey=color.rgb2gray(image)
plt.imshow(image_grey,cmap='gray')

# %%
filter=np.array([[1,2,1],
                [0,0,0],
                 [-1,-2,-1]])

# %%
convolution = convolve2d(image_grey,filter,mode='same',boundary='symm')

# %%
plt.imshow(convolution,cmap='gray')
